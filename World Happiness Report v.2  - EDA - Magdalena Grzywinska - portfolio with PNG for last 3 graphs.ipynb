# %% [markdown]
# # <span style="color:darkgreen"> World Happiness Report
#
#
# ### Exploratory Data Analysis (EDA)
#
# by **Magdalena Grzywinska**

# %% [markdown]
#  ![WHR%20image.png](attachment:WHR%20image.png)

# %% [markdown]
# The World Happiness Report is an annual assessment produced by the United Nations Sustainable Development Solutions Network to evaluate and rank countries based on the happiness and well-being of their citizens.
#
# It considers a range of factors such as economic conditions, social support, life expectancy, personal freedoms, generosity, and perceptions of corruption. By collecting data through surveys conducted worldwide, the report aims to offer insights into the elements that contribute to people's happiness.
#
# The ultimate goal is to encourage policymakers to prioritize the enhancement of citizens' well-being alongside more traditional economic measures like GDP. The report provides a global ranking of countries, shedding light on trends and factors that impact overall happiness.
#
# Source: https://worldhappiness.report/
#
# Using quantitative measures, the report analyses six qualitative characteristics to determine how they affect a country’s population’s happiness.
#
#
#
# ### Variable Description
#
#
# **GDP per capita**
#
# Gross Domestic Product, or how much each country produces, divided by the number of people in the country. GDP per capita gives information about the size of the economy and how the economy is performing
#
# **Social Support**
#
# Social support, or having someone to count on in times of trouble. “If you were in trouble, do you have relatives or friends you can count on to help you whenever you need them, or not?”
#
# **Healthy Life Expectancy**
#
# More than life expectancy, how is your physical and mental health? Mental health is a key component of subjective well-being and is also a risk factor for future physical health and longevity. Mental health influences and drives a number of individual choices, behaviours, and outcomes.
#
# **Freedom to make Life Choices**
#
# “Are you satisfied or dissatisfied with your freedom to choose what you do with your life?” This also includes Human Rights. Inherent to all human beings, regardless of race, sex, nationality, ethnicity, language, religion, or any other status. Human rights include the right to life and liberty, freedom from slavery and torture, freedom of opinion and expression, the right to work and education, and many more. Everyone is entitled to these rights without discrimination.
#
# **Generosity**
#
# “Have you donated money to a charity in the past month?” A clear marker for a sense of positive community engagement and a central way that humans connect with each other. Research shows that in all cultures, starting in early childhood, people are drawn to behaviours which benefit other people.
#
# **Perception of Corruption**
#
# “Is corruption widespread throughout the government or not” and “Is corruption widespread within businesses or not?” Do people trust their governments and have trust in the benevolence of others?
#
# **Dystopia**
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose of establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom, and least social support, it is referred to as “Dystopia,” in contrast to Utopia.

# %% [markdown]
# ### Loading packages

# %%
#To handle dataset:

import pandas as pd
import numpy as np 

#To make plots and visualize the data:

import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %% [markdown]
# ### Importing datasets

# %%
WHR_2023 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2023.csv')
WHR_2022 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2022.csv')
WHR_2021 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2021.csv')
WHR_2020 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2020.csv')
WHR_2019 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2019.csv')
WHR_2018 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2018.csv')
WHR_2017 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2017.csv')
WHR_2016 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2016.csv')
WHR_2015 = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/2015.csv')


continents = pd.read_csv('M:\Data Analyst\Cambridge Spark - Skills Bootcamp - Data analyst - Oct 23\Portfolio\MG - Porftolio - FINISHED - Happiness raport/continents.csv')

# %% [markdown]
# ### Understanding the data

# %%
WHR_2015.info(), WHR_2016.info(), WHR_2017.info(), WHR_2018.info(), WHR_2019.info(),\
WHR_2020.info(), WHR_2021.info(), WHR_2022.info(), WHR_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
WHR_2015.shape, WHR_2016.shape, WHR_2017.shape, WHR_2018.shape, WHR_2019.shape,\
WHR_2020.shape, WHR_2021.shape, WHR_2022.shape, WHR_2023.shape
# Out:
# ((158, 12),
#  (157, 13),
#  (155, 12),
#  (156, 9),
#  (156, 9),
#  (153, 20),
#  (149, 20),
#  (147, 12),
#  (137, 19))

# %% [markdown]
# Note: We have imported 9 csv files that contains the report from 2015 to 2023.
#
#   There are null-values in report for year 2018, 2022, 2023.
#
#    Reports have different number of columns.
#    lets investigate further the **column for each year**

# %%
for WHR in [WHR_2015, WHR_2016, WHR_2017, WHR_2018, WHR_2019,\
    WHR_2020, WHR_2021, WHR_2022, WHR_2023]:
    print (WHR.shape, WHR.columns, '\n')
# Out:
# (158, 12) Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
#
# (157, 13) Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
#
# (155, 12) Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
#
# ...

# %% [markdown]
# **Findings**: there are not only diffrences in number of columns for each report but also there is lack of consistency in column names
#
#
#
# **Action**:
# - to drop columns that are not included in all reports
# - to rename columns and achieve consistancy where working with analysis for multiple years
# - to add new "year" column to all datasets based on year of report
# - to include new "region" and "sub_region" columns using continents dataset
# - to remove non-value entries
# - to create one big dataset containing all the years from 2015 to 2023

# %% [markdown]
# ## Data Cleaning and Formatting

# %% [markdown]
# #### Adding "year" column to all WHR reports

# %%
#Add year column
yrs = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
dfs = [WHR_2015, WHR_2016, WHR_2017, WHR_2018, WHR_2019, WHR_2020, WHR_2021, WHR_2022, WHR_2023]
for i in range(0,9):
    dfs[i]['year'] = yrs[i]

# %%
WHR_2023.head(1)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    71.15                         0.961      -0.019
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# 0                      0.182                     1.778
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.888                         1.585
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.535
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.772                     0.126
#
# ...

# %% [markdown]
# #### Dropping irrelevant columns  for each year

# %% [markdown]
# **2015** World Happiness report

# %%
WHR_2015.head(1)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual  year
# 0     0.29678            2.51738  2015

# %% [markdown]
# region here is actualy sub-region - column to remove

# %%
columns_to_drop_2015 = ['Happiness Rank', 'Region','Standard Error', 'Dystopia Residual']
WHR_2015_cd = WHR_2015.drop(columns_to_drop_2015, axis=1)

# %%
WHR_2015_cd.head(1)
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)   Family  \
# 0  Switzerland            7.587                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  year
# 0     0.29678  2015

# %% [markdown]
# **2016** World Happiness report

# %%
columns_to_drop_2016 = ['Happiness Rank', 'Region','Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual']
WHR_2016_cd = WHR_2016.drop(columns_to_drop_2016, axis=1)

# %%
WHR_2016_cd.head(1)
# Out:
#    Country  Happiness Score  Economy (GDP per Capita)   Family  \
# 0  Denmark            7.526                   1.44178  1.16374
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.79504  0.57941                        0.44453
#
#    Generosity  year
# 0     0.36171  2016

# %% [markdown]
# **2017** World Happiness report

# %%
WHR_2017.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  year
# 0    0.362012                       0.315964           2.277027  2017

# %%
columns_to_drop_2017 = ['Happiness.Rank', 'Whisker.high','Whisker.low', 'Dystopia.Residual']
WHR_2017_cd = WHR_2017.drop(columns_to_drop_2017, axis=1)

# %%
WHR_2017_cd.head(1)
# Out:
#   Country  Happiness.Score  Economy..GDP.per.Capita.    Family  \
# 0  Norway            7.537                  1.616463  1.533524
#
#    Health..Life.Expectancy.   Freedom  Generosity  \
# 0                  0.796667  0.635423    0.362012
#
#    Trust..Government.Corruption.  year
# 0                       0.315964  2017

# %% [markdown]
# **2018** World Happiness report

# %%
WHR_2018.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
#
#    Perceptions of corruption  year
# 0                      0.393  2018

# %%
columns_to_drop_2018 = ['Overall rank']
WHR_2018_cd = WHR_2018.drop(columns_to_drop_2018, axis=1)

# %%
WHR_2018_cd.head(1)
# Out:
#   Country or region  Score  GDP per capita  Social support  \
# 0           Finland  7.632           1.305           1.592
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
#
#    Perceptions of corruption  year
# 0                      0.393  2018

# %% [markdown]
# **2019** World Happiness report

# %%
WHR_2019.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption  year
# 0                      0.393  2019

# %%
columns_to_drop_2019 = ['Overall rank']
WHR_2019_cd = WHR_2019.drop(columns_to_drop_2019, axis=1)

# %%
WHR_2019_cd.head(1)
# Out:
#   Country or region  Score  GDP per capita  Social support  \
# 0           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption  year
# 0                      0.393  2019

# %% [markdown]
# **2020** World Happiness report

# %%
WHR_2020.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267         0.95433                71.900825
#
#    Freedom to make life choices  ...  Perceptions of corruption  \
# 0                      0.949172  ...                   0.195445
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                           1.28519
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
# ...

# %%
columns_to_drop_2020 = ['Regional indicator', 'Standard error of ladder score', 'upperwhisker',
                        'lowerwhisker', 'Ladder score in Dystopia', 'Explained by: Log GDP per capita',
                        'Explained by: Social support', 'Explained by: Healthy life expectancy',
                        'Explained by: Freedom to make life choices', 'Explained by: Generosity',
                        'Explained by: Perceptions of corruption', 'Dystopia + residual']
                       
WHR_2020_cd = WHR_2020.drop(columns_to_drop_2020, axis=1)

# %%
WHR_2020_cd.head(1)
# Out:
#   Country name  Ladder score  Logged GDP per capita  Social support  \
# 0      Finland        7.8087              10.639267         0.95433
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                71.900825                      0.949172   -0.059482
#
#    Perceptions of corruption  year
# 0                   0.195445  2020

# %% [markdown]
# **2021** World Happiness report

# %%
WHR_2021.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904          7.78
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
#
#    Freedom to make life choices  ...  Perceptions of corruption  \
# 0                         0.949  ...                      0.186
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
# ...

# %%
columns_to_drop_2021 = ['Regional indicator', 'Standard error of ladder score', 'upperwhisker',
                        'lowerwhisker', 'Ladder score in Dystopia', 'Explained by: Log GDP per capita',
                        'Explained by: Social support', 'Explained by: Healthy life expectancy',
                        'Explained by: Freedom to make life choices', 'Explained by: Generosity',
                        'Explained by: Perceptions of corruption', 'Dystopia + residual']
                       
WHR_2021_cd = WHR_2021.drop(columns_to_drop_2021, axis=1)

# %%
WHR_2021_cd.head(1)
# Out:
#   Country name  Ladder score  Logged GDP per capita  Social support  \
# 0      Finland         7.842                 10.775           0.954
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
#
#    Perceptions of corruption  year
# 0                      0.186  2021

# %% [markdown]
# **2022** World Happiness report

# %%
WHR_2022.head(1)
# Out:
#    RANK  Country Happiness score  Whisker-high  Whisker-low  \
# 0     1  Finland             7.82          7.89        7.76
#
#    Dystopia (1.83) + residual   Explained by: GDP per capita   \
# 0                         2.52                           1.89
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.0                                  0.775
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.736                     0.109
#
#    Explained by: Perceptions of corruption  year
# 0                                    0.534  2022

# %%
columns_to_drop_2022 = ['RANK', 'Whisker-high ', 'Whisker-low',
       'Dystopia (1.83) + residual ' ]
WHR_2022_cd = WHR_2022.drop(columns_to_drop_2022, axis=1)

# %%
WHR_2022_cd.head(1)
# Out:
#    Country Happiness score   Explained by: GDP per capita   \
# 0  Finland             7.82                           1.89
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.0                                  0.775
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.736                     0.109
#
#    Explained by: Perceptions of corruption  year
# 0                                    0.534  2022

# %% [markdown]
# **2023** World Happiness report

# %%
WHR_2023.head(1)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    71.15                         0.961      -0.019
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# 0                      0.182                     1.778
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.888                         1.585
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.535
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.772                     0.126
#
# ...

# %%
columns_to_drop_2023 = ['Standard error of ladder score', 'upperwhisker',
                        'lowerwhisker', 'Ladder score in Dystopia', 'Explained by: Log GDP per capita',
                        'Explained by: Social support', 'Explained by: Healthy life expectancy',
                        'Explained by: Freedom to make life choices', 'Explained by: Generosity',
                        'Explained by: Perceptions of corruption', 'Dystopia + residual']
                       
WHR_2023_cd = WHR_2023.drop(columns_to_drop_2023, axis=1)

# %%
WHR_2023_cd.head(1)
# Out:
#   Country name  Ladder score  Logged GDP per capita  Social support  \
# 0      Finland         7.804                 10.792           0.969
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    71.15                         0.961      -0.019
#
#    Perceptions of corruption  year
# 0                      0.182  2023

# %% [markdown]
# #### Renaming columns for each year
#
# for all variables we would use consistance **headers**:
#
#
# country,
#
# happiness_score,
#
# economy_GDP_per_capita,
#
# freedom_to_make_life_choices,
#
# generosity,
#
# healthy_life_expectancy,
#
# social_support_family,
#
# trust_perceptions_of_corruption,
#
# rank

# %%
yrs = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
dfs_cd = [WHR_2015_cd, WHR_2016_cd, WHR_2017_cd, WHR_2018_cd, WHR_2019_cd, WHR_2020_cd, WHR_2021_cd, WHR_2022_cd, WHR_2023_cd]
for i in range(len(dfs_cd)):
    dfs_cd[i].rename(columns={
    'Country' : 'country', 'Country or region' : 'country', 'Country name' : 'country',
    'Economy (GDP per Capita)' : 'economy_GDP_per_capita', 'Economy..GDP.per.Capita.' : 'economy_GDP_per_capita', 'Explained by: GDP per capita' : 'economy_GDP_per_capita', 'Explained by: Log GDP per capita' : 'economy_GDP_per_capita', 'GDP per capita' : 'economy_GDP_per_capita', 'Logged GDP per capita' : 'economy_GDP_per_capita', 'Explained by: GDP per capita ' : 'economy_GDP_per_capita', 
    'Explained by: Freedom to make life choices' : 'freedom_to_make_life_choices',
    'Freedom' : 'freedom_to_make_life_choices', 'Freedom to make life choices' : 'freedom_to_make_life_choices', 
    'Explained by: Generosity' : 'generosity', 'Generosity' : 'generosity',
    'Explained by: Healthy life expectancy' : 'healthy_life_expectancy', 'Health (Life Expectancy)' : 'healthy_life_expectancy', 'Health..Life.Expectancy.' : 'healthy_life_expectancy', 'Healthy life expectancy' : 'healthy_life_expectancy',
    'Happiness Rank' : 'happiness_score', 'Happiness score' : 'happiness_score', 'Happiness score ': 'happiness_score','Happiness.Rank' : 'happiness_score','Happiness.Score' : 'happiness_score', 'Happiness Score' : 'happiness_score', 
    'Ladder score' : 'happiness_score',  'Score' : 'happiness_score', 
    'Explained by: Social support' : 'social_support_family', 'Family' : 'social_support_family', 'Social support' : 'social_support_family',
    'Explained by: Perceptions of corruption' : 'trust_perceptions_of_corruption', 'Perceptions of corruption' : 'trust_perceptions_of_corruption', 'Trust (Government Corruption)' : 'trust_perceptions_of_corruption', 'Trust..Government.Corruption.' : 'trust_perceptions_of_corruption'},inplace=True)

# %%
yrs = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
dfs_cd = [WHR_2015_cd, WHR_2016_cd, WHR_2017_cd, WHR_2018_cd, WHR_2019_cd, WHR_2020_cd, WHR_2021_cd, WHR_2022_cd, WHR_2023_cd]


print("Columns after renaiming\n")
for i in range(len(dfs_cd)):
    print(yrs[i], '\n')
    print(dfs_cd[i].columns, '\n')
# Out:
# Columns after renaiming
#
# 2015
#
# Index(['country', 'happiness_score', 'economy_GDP_per_capita',
#        'social_support_family', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'trust_perceptions_of_corruption',
#        'generosity', 'year'],
#       dtype='object')
#
# 2016
#
# Index(['country', 'happiness_score', 'economy_GDP_per_capita',
#        'social_support_family', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'trust_perceptions_of_corruption',
#        'generosity', 'year'],
#       dtype='object')
#
# 2017
#
# Index(['country', 'happiness_score', 'economy_GDP_per_capita',
#        'social_support_family', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'trust_perceptions_of_corruption', 'year'],
#       dtype='object')
#
# 2018
#
# Index(['country', 'happiness_score', 'economy_GDP_per_capita',
#        'social_support_family', 'healthy_life_expectancy',
# ...

# %%
WHR_2015_cd.shape, WHR_2016_cd.shape, WHR_2017_cd.shape, WHR_2018_cd.shape, WHR_2019_cd.shape,\
WHR_2020_cd.shape, WHR_2021_cd.shape, WHR_2022_cd.shape, WHR_2023_cd.shape
# Out:
# ((158, 9),
#  (157, 9),
#  (155, 9),
#  (156, 9),
#  (156, 9),
#  (153, 9),
#  (149, 9),
#  (147, 9),
#  (137, 9))

# %% [markdown]
# **Missing values**

# %%
WHR_2015_cd.info(), WHR_2016_cd.info(), WHR_2017_cd.info(), WHR_2018_cd.info(), WHR_2019_cd.info(),\
WHR_2020_cd.info(), WHR_2021_cd.info(), WHR_2022_cd.info(), WHR_2023_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          158 non-null    object
#  1   happiness_score                  158 non-null    float64
#  2   economy_GDP_per_capita           158 non-null    float64
#  3   social_support_family            158 non-null    float64
#  4   healthy_life_expectancy          158 non-null    float64
#  5   freedom_to_make_life_choices     158 non-null    float64
#  6   trust_perceptions_of_corruption  158 non-null    float64
#  7   generosity                       158 non-null    float64
#  8   year                             158 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 11.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
# ...

# %% [markdown]
# non-null values:
#
# WHR_2015 - none
#
# WHR_2016 - none
#
#
# WHR_2017 - none
#
# WHR_2018 - missing value in 'trust_perceptions_of_corruption'
#
# WHR_2019 - none
#
# WHR_2020 - none
#
# WHR_2021 - none
#
# WHR_2022 - missing value in most of the columumns for one entry (Palestine)
#
# WHR_2023 - missing value in healthy_life_expectancy

# %%
WHR_2023_cd.dropna(axis=0, inplace=True)

# %%
WHR_2022_cd.dropna(axis=0, inplace=True)

# %%
WHR_2018_cd.dropna(axis=0, inplace=True)

# %%
WHR_2015_cd.info(), WHR_2016_cd.info(), WHR_2017_cd.info(), WHR_2018_cd.info(), WHR_2019_cd.info(),\
WHR_2020_cd.info(), WHR_2021_cd.info(), WHR_2022_cd.info(), WHR_2023_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          158 non-null    object
#  1   happiness_score                  158 non-null    float64
#  2   economy_GDP_per_capita           158 non-null    float64
#  3   social_support_family            158 non-null    float64
#  4   healthy_life_expectancy          158 non-null    float64
#  5   freedom_to_make_life_choices     158 non-null    float64
#  6   trust_perceptions_of_corruption  158 non-null    float64
#  7   generosity                       158 non-null    float64
#  8   year                             158 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 11.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 9 columns):
# ...

# %% [markdown]
# there are no missing values in any of WHR reports

# %% [markdown]
# **Creating new ranking column 'rank'**

# %% [markdown]
# Let's create new 'rank' column foe each year based on happiness_score.
#
# Higher the score - higher the ranking would be

# %%
yrs = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
dfs_cd = [WHR_2015_cd, WHR_2016_cd, WHR_2017_cd, WHR_2018_cd, WHR_2019_cd, WHR_2020_cd, WHR_2021_cd, WHR_2022_cd, WHR_2023_cd]

for i in range(len(dfs_cd)):
    dfs_cd[i]['rank'] = dfs_cd[i]['happiness_score'].rank(method='dense', ascending=False) .astype(int)

# %%
WHR_2015_cd.shape, WHR_2016_cd.shape, WHR_2017_cd.shape, WHR_2018_cd.shape, WHR_2019_cd.shape,\
WHR_2020_cd.shape, WHR_2021_cd.shape, WHR_2022_cd.shape, WHR_2023_cd.shape

#to check if number of columns increase from 9 to 10
# Out:
# ((158, 10),
#  (157, 10),
#  (155, 10),
#  (155, 10),
#  (156, 10),
#  (153, 10),
#  (149, 10),
#  (145, 10),
#  (136, 10))

# %%
WHR_2023_cd.head()
# Out:
#        country  happiness_score  economy_GDP_per_capita  \
# 0      Finland            7.804                  10.792
# 1      Denmark            7.586                  10.962
# 2      Iceland            7.530                  10.896
# 3       Israel            7.473                  10.639
# 4  Netherlands            7.403                  10.942
#
#    social_support_family  healthy_life_expectancy  \
# 0                  0.969                   71.150
# 1                  0.954                   71.250
# 2                  0.983                   72.050
# 3                  0.943                   72.697
# 4                  0.930                   71.550
#
#    freedom_to_make_life_choices  generosity  trust_perceptions_of_corruption  \
# 0                         0.961      -0.019                            0.182
# 1                         0.934       0.134                            0.196
# 2                         0.936       0.211                            0.668
# ...

# %% [markdown]
# **Adding new columns - 'region' and sub_region'**

# %% [markdown]
# lets check that all country for each year are a unique value

# %%
continents.columns
# Out:
# Index(['name', 'alpha-2', 'alpha-3', 'country-code', 'iso_3166-2', 'region',
#        'sub-region', 'intermediate-region', 'region-code', 'sub-region-code',
#        'intermediate-region-code'],
#       dtype='object')

# %%
continents.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG           4.0  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA         248.0  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB           8.0  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA          12.0  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM          16.0  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
# removing irrelevant columns

columns_to_drop_continents = ['alpha-2', 'alpha-3', 'iso_3166-2', 'country-code', 'intermediate-region', 'region-code', 'sub-region-code',
       'intermediate-region-code']

continents_cd = continents.drop(columns_to_drop_continents, axis=1 )

# %%
continents_cd.head()
# Out:
#              name   region       sub-region
# 0     Afghanistan     Asia    Southern Asia
# 1   Åland Islands   Europe  Northern Europe
# 2         Albania   Europe  Southern Europe
# 3         Algeria   Africa  Northern Africa
# 4  American Samoa  Oceania        Polynesia

# %%
# renaming the columns for consistency
continents_cd = continents_cd.rename({'name' : 'country', 'sub-region' : 'sub_region'}, axis=1)

# %%
continents_cd.head()
# Out:
#           country   region       sub_region
# 0     Afghanistan     Asia    Southern Asia
# 1   Åland Islands   Europe  Northern Europe
# 2         Albania   Europe  Southern Europe
# 3         Algeria   Africa  Northern Africa
# 4  American Samoa  Oceania        Polynesia

# %% [markdown]
# Creating new columns by merging WHR reports for each year with 'continents' detaframe
#
#
# we will be joining the df using 'country' column.

# %%
WHR_2015_region = WHR_2015_cd.merge(continents_cd, on='country', how='left')
WHR_2016_region = WHR_2016_cd.merge(continents_cd, on='country', how='left')
WHR_2017_region = WHR_2017_cd.merge(continents_cd, on='country', how='left')
WHR_2018_region = WHR_2018_cd.merge(continents_cd, on='country', how='left')
WHR_2019_region = WHR_2019_cd.merge(continents_cd, on='country', how='left')
WHR_2020_region = WHR_2020_cd.merge(continents_cd, on='country', how='left')
WHR_2021_region = WHR_2021_cd.merge(continents_cd, on='country', how='left')
WHR_2022_region = WHR_2022_cd.merge(continents_cd, on='country', how='left')
WHR_2023_region = WHR_2023_cd.merge(continents_cd, on='country', how='left')

# %%
WHR_2015_region.head() #to check the new columns: country, region and sub_region being added
# Out:
#        country  happiness_score  economy_GDP_per_capita  \
# 0  Switzerland            7.587                 1.39651
# 1      Iceland            7.561                 1.30232
# 2      Denmark            7.527                 1.32548
# 3       Norway            7.522                 1.45900
# 4       Canada            7.427                 1.32629
#
#    social_support_family  healthy_life_expectancy  \
# 0                1.34951                  0.94143
# 1                1.40223                  0.94784
# 2                1.36058                  0.87464
# 3                1.33095                  0.88521
# 4                1.32261                  0.90563
#
#    freedom_to_make_life_choices  trust_perceptions_of_corruption  generosity  \
# 0                       0.66557                          0.41978     0.29678
# 1                       0.62877                          0.14145     0.43630
# 2                       0.64938                          0.48357     0.34139
# ...

# %%
WHR_2015_region.shape, WHR_2016_region.shape, WHR_2017_region.shape, WHR_2018_region.shape, WHR_2019_region.shape,\
WHR_2020_region.shape, WHR_2021_region.shape, WHR_2022_region.shape, WHR_2023_region.shape


#to check if number of columns increase from 10 to 12
# Out:
# ((158, 12),
#  (157, 12),
#  (155, 12),
#  (155, 12),
#  (156, 12),
#  (153, 12),
#  (149, 12),
#  (145, 12),
#  (136, 12))

# %%
WHR_2023_region.columns
# Out:
# Index(['country', 'happiness_score', 'economy_GDP_per_capita',
#        'social_support_family', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'trust_perceptions_of_corruption', 'year', 'rank', 'region',
#        'sub_region'],
#       dtype='object')

# %% [markdown]
#
#
#
# **Creating one big dataframe containing all the years**

# %%
# number of unique countries for each year should match number of rows of each dataframe. 

for WHR in [WHR_2015_cd, WHR_2016_cd, WHR_2017_cd, WHR_2018_cd, WHR_2019_cd,
            WHR_2020_cd, WHR_2021_cd, WHR_2022_cd, WHR_2023_cd]:
    unique_countries_count = len(WHR['country'].unique())
    print(f'Unique countries count : {unique_countries_count}\n')
# Out:
# Unique countries count : 158
#
# Unique countries count : 157
#
# Unique countries count : 155
#
# Unique countries count : 155
#
# Unique countries count : 156
#
# Unique countries count : 153
#
# Unique countries count : 149
#
# Unique countries count : 145
#
# Unique countries count : 136

# %%
WHR_ALL_region = pd.concat([WHR_2015_region,
                            WHR_2016_region,
                            WHR_2017_region,
                            WHR_2018_region,
                            WHR_2019_region,
                            WHR_2020_region,
                            WHR_2021_region,
                            WHR_2022_region,
                            WHR_2023_region])


WHR_ALL_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1364 entries, 0 to 135
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          1364 non-null   object
#  1   happiness_score                  1364 non-null   object
#  2   economy_GDP_per_capita           1364 non-null   float64
#  3   social_support_family            1364 non-null   float64
#  4   healthy_life_expectancy          1364 non-null   float64
#  5   freedom_to_make_life_choices     1364 non-null   float64
#  6   trust_perceptions_of_corruption  1364 non-null   float64
#  7   generosity                       1364 non-null   float64
#  8   year                             1364 non-null   object
#  9   rank                             1364 non-null   int32
#  10  region                           1364 non-null   object
#  11  sub_region                       1364 non-null   object
# ...

# %%
#changing the datatype for 2 columns from string to number

WHR_ALL_region['happiness_score'] = WHR_ALL_region['happiness_score'].astype(float)
WHR_ALL_region['economy_GDP_per_capita'] = WHR_ALL_region['economy_GDP_per_capita'].astype(float)


WHR_ALL_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1364 entries, 0 to 135
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          1364 non-null   object
#  1   happiness_score                  1364 non-null   float64
#  2   economy_GDP_per_capita           1364 non-null   float64
#  3   social_support_family            1364 non-null   float64
#  4   healthy_life_expectancy          1364 non-null   float64
#  5   freedom_to_make_life_choices     1364 non-null   float64
#  6   trust_perceptions_of_corruption  1364 non-null   float64
#  7   generosity                       1364 non-null   float64
#  8   year                             1364 non-null   object
#  9   rank                             1364 non-null   int32
#  10  region                           1364 non-null   object
#  11  sub_region                       1364 non-null   object
# ...

# %%
#WHR_ALL_region.to_csv('WHR_ALLv2.csv') #use this script if you want to expoert WHR_ALL to csv file

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Average (mean)
#
#
#
# Calculating the mean happiness score for each region in the World Happiness Report for the year 2023

# %%
all_columns = ['country', 'happiness_score', 'economy_GDP_per_capita',
       'social_support_family', 'healthy_life_expectancy',
       'freedom_to_make_life_choices', 'generosity',
       'trust_perceptions_of_corruption', 'year', 'rank', 'region',
       'sub_region']

# %%
# Group by 'region' and calculate the mean happiness score
mean_happiness_region_2023 = WHR_2023_region.groupby('region')[['happiness_score']].mean()

# Sort the results in descending order based on the mean happiness score
mean_happiness_region_2023 = mean_happiness_region_2023.sort_values(by=['happiness_score'], ascending=False)

# Set a seaborn style
sns.set(style="whitegrid")

# Create a bar plot for mean happiness scores by region
plt.figure(figsize=(10, 6))
sns.barplot(x='happiness_score', y=mean_happiness_region_2023.index, data=mean_happiness_region_2023, palette="crest")

# Add labels and title
plt.xlabel('Mean Happiness Score')
plt.ylabel('Region')
plt.title('Average (mean) Happiness Score by Region in World Happiness Report 2023')

# Display the plot
plt.show()

# %%
# Group by 'sub-region' and calculate the mean happiness score
mean_happiness_sub_region_2023 = WHR_2023_region.groupby('sub_region')[['happiness_score']].mean()

# Sort the results in descending order based on the mean happiness score
mean_happiness_sub_region_2023 = mean_happiness_sub_region_2023.sort_values(by=['happiness_score'], ascending=False)

# Set a seaborn style
sns.set(style="whitegrid")

# Create a bar plot for mean happiness scores by region
plt.figure(figsize=(10, 6))
sns.barplot(x='happiness_score', y=mean_happiness_sub_region_2023.index, data=mean_happiness_sub_region_2023, palette="crest")

# Add labels and title
plt.xlabel('Mean Happiness Score')
plt.ylabel('Sub-Region')
plt.title('Average (mean) Happiness Score by Sub-Region in World Happiness Report 2023')

# Display the plot
plt.show()

# %% [markdown]
# ### Bar plots

# %% [markdown]
# Bar charts are typically used for discrete data, where each bar represents a distinct category or group.
#
# Bar plots are a type of data visualization used to represent data in the form of rectangular bars. The height of each bar represents the value of a data point, and the width of each bar represents the category of the data.
#
# The Matplotlib and Seaborn libraries in Python are widely used to create bar plots.
#
#
# **Here are some common use cases for bar plots:**
# - ***Comparing frequencies or counts*** of data points in different categories
# - ***Displaying proportions***
# - ***Visualizing changes over time***
# - ***Comparing multiple variables***
# - ***Displaying nominal data***

# %% [markdown]
# The ***most*** and the ***least*** happy countries in the world

# %%
# Creating top 20 and bottom 20 data frames 
top20_2023 = WHR_2023_region.set_index('country')['happiness_score'].nlargest(10).to_frame()
bottom20_2023 = WHR_2023_region.set_index('country')['happiness_score'].nsmallest(10).to_frame()

# Concatenate the two data frames
WHR_20_concat = pd.concat([top20_2023, bottom20_2023], axis=0)
WHR_20_concat = WHR_20_concat.sort_values(by='happiness_score')

# visualisation of the concatenated DataFrame
fig = plt.figure(figsize=(10,10))
cmap = plt.cm.GnBu
norm = plt.Normalize(vmin=WHR_20_concat['happiness_score'].min(), vmax=WHR_20_concat['happiness_score'].max())
colors = [cmap(norm(value)) for value in WHR_20_concat['happiness_score']]

g = plt.barh(y=WHR_20_concat.index, width=WHR_20_concat["happiness_score"], color=colors)
plt.ylabel("Country")
plt.xlabel("Happiness Score")
plt.title("Top and bottom happiest countries", fontsize = 20)

plt.show()

# %% [markdown]
# ***Top 10 Countries for Each Variable***

# %%
# This code organises the plots by factors such as happiness score,
# GDP per capita, healthy life expectancy, generosity, freedom, and trust. 
# Each subplot includes the top 10 countries for the respective factor.


fig, axes = plt.subplots(nrows=3, ncols=2,constrained_layout=True,figsize=(10,10))

# Plotting each factor
sns.barplot(x='happiness_score' ,y='country',
                        data=WHR_2023_region.nlargest(10,'happiness_score'),
                        ax=axes[0,0],palette='crest').set_title('Top 10 Countries by Happiness Score')
sns.barplot(x='economy_GDP_per_capita',y='country',
                        data=WHR_2023_region.nlargest(10,'economy_GDP_per_capita'),
                        ax=axes[0,1],palette='crest').set_title('Top 10 Countries by GDP per Capita')
sns.barplot(x='healthy_life_expectancy' ,y='country',
                        data=WHR_2023_region.nlargest(10,'healthy_life_expectancy'),
                        ax=axes[1,0],palette='crest').set_title('Top 10 Countries by Healthy Life Expectancy')
sns.barplot(x='generosity' ,y='country',
                        data=WHR_2023_region.nlargest(10,'generosity'),
                        ax=axes[1,1],palette='crest').set_title('Top 10 Countries by Generosity')
sns.barplot(x='freedom_to_make_life_choices' ,y='country',
                        data=WHR_2023_region.nlargest(10,'freedom_to_make_life_choices'),
                        ax=axes[2,0],palette='crest').set_title('Top 10 Countries by Freedom of Choices')
sns.barplot(x='trust_perceptions_of_corruption' ,y='country',
                        data=WHR_2023_region.nlargest(10,'trust_perceptions_of_corruption'),
                        ax=axes[2,1],palette='crest').set_title('Top 10 Countries by Trust in Institutions')
# Add a chart title
fig.suptitle('Top 10 Countries Across Various Factors', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Top 10 Countries Across Various Factors')

# %% [markdown]
#  ### Correlation matrix

# %% [markdown]
# **What is the correlation between each variable?**
#
# **Correlation heatmaps** - to show in a glance which variables are correlated, to what degree, in which direction, and alerts us to potential multicollinearity problems.

# %% [markdown]
#  **correlation heatmap** using **seaborn.heatmap**

# %%
# Selecting specific columns for the heatmap
columns_corr = ['happiness_score', 'economy_GDP_per_capita',
       'social_support_family', 'healthy_life_expectancy',
       'freedom_to_make_life_choices', 'generosity',
       'trust_perceptions_of_corruption']


corr_mx = sns.heatmap(WHR_2023_region.loc[:, WHR_2023_region.columns.isin(columns_corr)].corr(), annot=True, linewidth=0.5, cmap=sns.cubehelix_palette(as_cmap=True) )

corr_mx.set_title('Correlation Heatmap', fontdict={'fontsize':16}, pad=20);

# %% [markdown]
# A **diverging color palette** that has markedly different colors at the two ends of the value-range with a pale, almost colorless midpoint, works much better with correlation heatmaps

# %%
sns.set(style="ticks")

plt.figure(figsize=(16, 6))
corr_mx = sns.heatmap(WHR_2023_region.loc[:, WHR_2023_region.columns.isin(columns_corr)].corr(), vmin=-1, vmax=1,linewidth=0.5,  annot=True, cmap='BrBG')
corr_mx.set_title('Correlation Heatmap', fontdict={'fontsize':26}, pad=20);

# %% [markdown]
# Stronger correlation on both ends of the spectrum pops out in darker, weaker correlation in lighter shades.

# %% [markdown]
# ### Matrix of plots (pairwise relationships - scatter plots)

# %% [markdown]
# To plot multiple pairwise bivariate distributions in a dataset, you can use the . pairplot() function.

# %% [markdown]
# The most basic usage involves employing a **scatterplot** to visualize the relationships between variable pairs, complemented by **histplot** for the marginal plots along the diagonal:

# %%
sns.set(style="ticks")

plt.figure(figsize=(10, 7))

# Create a pairplot with scatter plots and histograms

sns.pairplot(
    WHR_2023_region[['region', 'happiness_score', 'economy_GDP_per_capita',
       'social_support_family', 'healthy_life_expectancy',
       'freedom_to_make_life_choices']],
    hue='region',
    diag_kind='hist',
    plot_kws=dict(marker="o", linewidth=1),
    diag_kws=dict(fill=False),
    height=2.5  
)

# Add a title
plt.suptitle("Pairplot of World Happiness Report 2023 by Region", y=1.02, fontsize=16)

# Adjust the layout to make space for the legend
plt.subplots_adjust(bottom=0.15)

# Show the plot
plt.show()
# Out:
# C:\Users\dymna\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Pairplot** can privide several **insights** into the World Happiness Report 2023 data by region:
#
# * Correlation between Variables:
#
#
# -Check the scatter plots to identify any patterns or correlations between the happiness score and other variables
#
# -Look for linear relationships or potential outliers.
#
# * Regional Differences:
#
# -Use the hue parameter to distinguish regions in the pairplot. This allows you to visually compare how different regions vary in terms of happiness and other factors.
#
#
# -Observe if there are distinct clusters or differences between regions.
#
# * Outlier Detection:
#
# -Identify any outliers in the scatter plots that may indicate countries with exceptional or unusual happiness scores or other features.
#
#
# -Outliers could be interesting points for further investigation.
#
#
# * Distribution of Variables:
#
# -Examine the histograms on the diagonal to understand the distribution of each variable.
#
#
# -Check for normality or skewness in the distributions.
#
#
#
# * Comparisons with Previous Years or Regions:
#
# -If you have data from previous years or additional regions, compare the patterns and relationships to identify any changes or consistent trends.

# %% [markdown]
# ### Histogram

# %% [markdown]
# Histograms are used to visualize the distribution of a continuous data set.
#
# They show the density of values within different ranges.
#
#
# The data is divided into intervals or bins, and the height of each bar represents the frequency or count of data points falling into that interval.

# %%
#the Variability of Each Metric using Histogram plot.


# Create histograms for each column

WHR_2023_region[['happiness_score', 'economy_GDP_per_capita',
       'social_support_family', 'healthy_life_expectancy',
       'freedom_to_make_life_choices', 'generosity',
       'trust_perceptions_of_corruption']].hist(bins=20);

# Adjust layout for better spacing
plt.subplots_adjust(hspace=0.5)

# Add a main title
plt.suptitle('Histograms of World Happiness Report 2023', y=1.02, fontsize=16)
# Out:
# Text(0.5, 1.02, 'Histograms of World Happiness Report 2023')

# %% [markdown]
# Histograms for various factors from the World Happiness Report 2023, allowing you to visually explore the distribution of each variable.
#
# By examining these histograms collectively, you can identify trends, outliers, or patterns in the distribution of happiness-related factors. For example, you may observe whether there are consistent disparities across regions or if certain factors exhibit a similar distribution. Additionally, you can use these visualizations to compare different factors and their potential impact on overall happiness scores.

# %%
WHR_ALL_region[['happiness_score']].hist(bins=100)

# Add a main title
plt.suptitle('Histograms of Happiness Score accross years 2015-2023' , y=1.02, fontsize=16)
plt.axvline(x = WHR_ALL_region['happiness_score'].mean(), color = 'orange')
plt.axvline(x = WHR_ALL_region['happiness_score'].median(), color = 'yellow')

# %% [markdown]
# ###  Outliers - Box plot

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a statistical visualization that provides a summary of the distribution of a dataset. It displays key statistical measures such as the ***median***, ***quartiles***, and potential ***outliers***.
#
# **Outliers** can provide insights into unusual or extreme values in the dataset.

# %%
# Set a seaborn style
sns.set(style='whitegrid')

# Order the regions by mean happiness score
order_regions = mean_happiness_sub_region_2023.index

# Create a boxplot for happiness scores by region
fig, ax = plt.subplots(figsize=(12,10))
sns.boxplot(y='sub_region', x='happiness_score', data=WHR_2023_region, orient='h', ax=ax, palette='crest', order=order_regions)

# Set title and labels
plt.title('Happiness Score Boxplot by Sub-Region - World Happiness Report 2023', fontsize=18)
plt.xlabel('Happiness Score')
plt.ylabel('Sub-Region')

# Increase the size of ticks on both axes
ax.tick_params(axis='both', which='major', labelsize=14)

# Display the plot
plt.show()

# %% [markdown]
# A boxplot is used to visualize the distribution of happiness scores across different sub-regions based on the World Happiness Report 2023 data. Here are some insights you can potentially gather from the plot:
#
# * Variability in Happiness Scores:
# The boxplot allows you to observe the spread or variability in happiness scores within each sub-region. The length of the boxes and the presence of outliers can indicate regions with diverse levels of happiness.
#
# * Median Happiness Scores:
# The horizontal line inside each box represents the median happiness score for each sub-region. Comparing the medians can give you an idea of the central tendency of happiness within different areas.
#
# * Outliers:
# Points outside the whiskers of the boxplot may indicate outliers—regions with exceptionally high or low happiness scores. These outliers can be interesting to investigate further, as they might provide insights into factors influencing happiness.
#
# * Comparisons between Sub-Regions:
# By ordering the sub-regions based on mean happiness scores, you can observe the relative happiness levels. Sub-regions with higher mean scores will be positioned towards the top of the plot, while those with lower mean scores will be towards the bottom.
#
# * Patterns and Trends:
# Examining the overall shape of the boxplot can reveal patterns and trends in happiness scores. For example, if certain sub-regions consistently have higher or lower scores, it may suggest underlying factors influencing happiness in those areas.
#
# * Data Distribution:
# The width of the boxes and the length of the whiskers provide insights into the distribution of happiness scores within each sub-region. A wider box and longer whiskers indicate greater variability in scores.
#
# By interpreting these elements of the boxplot, you can gain a visual understanding of the happiness scores across different sub-regions, allowing for comparisons and identifying potential areas of interest for further analysis.

# %% [markdown]
# ### Sunburst plot

# %% [markdown]
# This sunburst plot will help you visualize the hierarchical structure of regions, sub-regions, and countries, with the color indicating the happiness score.

# %%
#Sunburst plot looking at the make up of the regions and sub-regions and countires
# and how the happiness score of each country and sun_region compares with others in the same category

fig = px.sunburst(data_frame=WHR_2023_region,
                  path=["region", "sub_region", "country"],
                  values="happiness_score",
                  color="happiness_score",
                  color_continuous_scale='BrBG',
                  width=700, 
                  height=700,
                  title = 'Happiness score sunburst - region / sub region / country')
fig.show()
# Out:
# <div>                            <div id="25342c6c-93f3-4a3c-b882-a5b1088fdde8" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25342c6c-93f3-4a3c-b882-a5b1088fdde8")) {                    Plotly.newPlot(                        "25342c6c-93f3-4a3c-b882-a5b1088fdde8",                        [{"branchvalues":"total","customdata":[[1.859],[5.277],[5.329],[6.024],[5.342],[7.095],[7.097000000000001],[6.173000000000001],[4.282],[6.859],[4.374],[5.684],[5.633],[3.435],[6.125],[5.466],[4.638],[4.393],[4.973],[6.961],[4.397],[6.334],[5.818],[5.63],[3.545],[5.267],[3.207],[6.609],[6.125],[6.130000000000001],[6.845000000000001],[7.586],[5.569],[5.559],[4.17],[6.122],[6.455],[4.091],[7.804],[6.661],[5.035],[4.279],[5.109],[6.892],[4.605],[5.931],[6.15],[5.072]
# ...

# %% [markdown]
# ### Happiness Sunburst Plot - region / sub region / country (.png)
#
# ![Sunburst%20plot.png](attachment:Sunburst%20plot.png)

# %% [markdown]
# ### Trend analysis - line charts

# %%
countries=['Finland', 'Denmark', 'Israel','Netherlands', 'Norway', 'United States','United Kingdom','China', 'Poland', 'Nigeria']

# %% [markdown]
# **Happiness Score Trends Over Time**
#
# You can observe how the happiness scores change over the years for the selected countries.
# Identify whether there are any overall trends in happiness scores, such as an increase, decrease, or stability.

# %%
df_i=WHR_ALL_region[WHR_ALL_region['country'].isin(countries)]
line_chart=px.line(df_i, x='year', y='happiness_score',color='country',title='Countries Trend - Happiness Score 2015-2023')
line_chart.update_layout(
    plot_bgcolor='white',
    paper_bgcolor='white'
)
line_chart.show()
# Out:
# <div>                            <div id="e95c10b2-0cd1-47ad-8aa8-ffa871b0b0b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e95c10b2-0cd1-47ad-8aa8-ffa871b0b0b0")) {                    Plotly.newPlot(                        "e95c10b2-0cd1-47ad-8aa8-ffa871b0b0b0",                        [{"hovertemplate":"country=Denmark<br>year=%{x}<br>happiness_score=%{y}<extra></extra>","legendgroup":"Denmark","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Denmark","orientation":"v","showlegend":true,"x":["2015","2016","2017","2018","2019","2020","2021","2022","2023"],"xaxis":"x","y":[7.527,7.526,7.521999836,7.555,7.6,7.645599842,7.62,7.64,7.586],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Norway<br>ye
# ...

# %% [markdown]
# ### Countries Trend - Happiness Score 2015-2023 (.png)
#
# ![Trends%202019-2023%20-%20Happiness%20score.png](attachment:Trends%202019-2023%20-%20Happiness%20score.png)

# %% [markdown]
# The lines represent different countries, allowing you to compare the happiness scores of multiple countries on a single chart.
# Notice if there are consistent patterns or significant variations between countries.
# Yearly Changes:
#
#
# Look for correlations between significant events (economic, social, political) and corresponding changes in happiness scores.
# Interactivity:
#
# You can hover over data points to see specific values, making it easier to explore details.

# %%
df_i=WHR_ALL_region[WHR_ALL_region['country'].isin(countries)]
line_chart=px.line(df_i, x='year', y='generosity',color='country',title='Countries Trend - Generosity 2015-2023')
line_chart.update_layout(
    plot_bgcolor='white',
    paper_bgcolor='white')
line_chart.show()
# Out:
# <div>                            <div id="448e071c-05c7-4ea2-b1ae-acbe3df06c0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("448e071c-05c7-4ea2-b1ae-acbe3df06c0a")) {                    Plotly.newPlot(                        "448e071c-05c7-4ea2-b1ae-acbe3df06c0a",                        [{"hovertemplate":"country=Denmark<br>year=%{x}<br>generosity=%{y}<extra></extra>","legendgroup":"Denmark","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Denmark","orientation":"v","showlegend":true,"x":["2015","2016","2017","2018","2019","2020","2021","2022","2023"],"xaxis":"x","y":[0.34139,0.36171,0.355280489,0.284,0.252,0.066201776,0.03,0.188,0.134],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Norway<br>
# ...

# %% [markdown]
# ### Countries Trend -  Generosity 2015-2023 (.png)
#
#
# ![Trends%202019-2023%20-%20Generosity.png](attachment:Trends%202019-2023%20-%20Generosity.png)
